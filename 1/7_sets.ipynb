# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
set1 = {"hello",100,"hello",13.12,100,100,"hii"}

print(set1)
print(len(set1)) #no. of unique elements in the set
print(type(set1))
# Out:
# {'hii', 100, 13.12, 'hello'}
# 4
# <class 'set'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
set1 = {100, 13.12, 'hii', 'hello'}

set1.add(1)
set1.add(100)

# set1.clear()

print(set1)
# Out:
# {1, 'hii', 100, 13.12, 'hello'}

# %%
set1 = {100, 13.12, 'hii', 'hello'}

set1.add(1)
set1.add(100)

set1.clear()

print(set1)
# Out:
# set()

# %%
set1 = {100, 13.12, 'hii', 'hello'}

set1.add(1)
set1.add(100)

set1.discard(100)
set1.discard(1000)

print(set1)
# Out:
# {1, 'hii', 13.12, 'hello'}

# %%
s = "sourav"

print(s[2])
# Out:
# u
