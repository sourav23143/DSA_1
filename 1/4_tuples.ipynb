# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tuple1 = (3,"hello",1032.2,"hii",True)

print(len(tuple1))
print(list(tuple1))
print(tuple1[3])
print(tuple1[-2])
# Out:
# 5
# [3, 'hello', 1032.2, 'hii', True]
# hii
# hii

# %% [markdown]
# ![image.png](attachment:image.png)
